# %%
from prediction import *

# %%
test_image_path = "sample_2.jpeg" #path for test image 
weight_paths = "weights.pth"
star_library = "../data/star-library"##prediction folder path
prediction(test_image_path,weight_paths,star_library)
# Out:
# Loaded pretrained weights for efficientnet-b3
# Prediction star: <function prediction at 0x00000207DDF57048>, its similarity is 0.5

# %%
vector_library_path = "../data/vector_library.csv"
vectorcompare(test_image_path,weight_paths,vector_library_path)
# Out:
# Loaded pretrained weights for efficientnet-b3
